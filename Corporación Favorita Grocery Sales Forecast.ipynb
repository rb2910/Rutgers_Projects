# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color= dodgerblue> Corporación Favorita Grocery Sales Forecasting </font>
#
# ### REF - https://www.kaggle.com/c/favorita-grocery-sales-forecasting

# %% [markdown]
# ### Overview
#
# Corporación Favorita, a large Ecuadorian-based grocery retailer operate hundreds of supermarkets, with over 200,000 different products on their shelves. They have challenged the Kaggle community to build a model that more accurately forecasts product sales.
#
# We want to build a model that more accurately Forecasts Product Sales for diffirent items sold at different Favorita stores located in Ecuador. Store sales are influenced by many factors, including promotions, competition, school and state holidays, seasonality, and locality. With thousands of individual managers predicting sales based on their unique circumstances, the accuracy of results can be quite varied.

# %% [markdown]
# ### Propose question for your project.
# The following questions will be used to explore and analyse the Corporación Favorita stores to predict the target variable 'Unit sales' of the dataset.
#
# 1. Can we build a model to forecast/predict the sales for Corporación Favorita ?
#
# 2. Can we segment (ABC Analysis) the product families  to based on their sales ? Which are the "A" items that has sales of about 80% in a store?
#
# 3. Does new product introductions affect the total unit sales?
#
# 4. what is the percentage increase/decrease of total unit sales , when products are offered on promotion on a particular date?
#
# 5. What is the ratio of sales and transaction over time?
#
# 6. Does increase in transactions lead to increase in sales?
#
# 7. How does location of the stores play an important role in increasing the total unit sales?
#
# 8. How does Holiday-events at Ecuador affect the Grocery sales including the transfered type(A holiday that is transferred officially falls on that calendar day,but was moved to another date by the government) and Bridge type holidays(Days that are type Bridge are extra days that are added to a holiday (e.g., to extend the break across a long weekend))?
#
# 9. Ecuador is an oil-dependent country and it's economical health is highly vulnerable to shocks in oil prices. So how does the oil price affect the logistic cost of the store and in turn the grocery sales? Is there a connection between oil price and the Supermarket sales?
#
# 10. What is the growth margin for favorita stores as compared to its competitors given the size of favorita stores.

# %% [markdown]
# ###  Explain why it is an interesting question.
#
# Brick-and-mortar grocery stores are always in a delicate dance with purchasing and sales forecasting.
#
# If they predict a little over, and grocers are stuck with overstocked, perishable goods and if they predict a little under, popular items quickly sell out, leaving money on the table and customers fuming.
#
# So, they want to optimize the inventory they are holding so that the holding cost is minimized, they do not want to lock extra money and also they do not want to lose sales.
#
# This problem becomes more complex and interesting as retailers add new locations with unique needs, new products, ever transitioning seasonal tastes, and unpredictable product marketing.
#
# Corporación Favorita, currently rely on subjective forecasting methods with very little data to back them up and very little automation to execute plans.
#
# This project explores how machine learning could better ensure customer satisfaction by having just enough of the right products at the right time.

# %% [markdown]
# ### What data will you use to answer it?
#  The following data will be used and explored to answer the questions proposed for the project.
#  Corporación Favorita, has provided us with us with 3 types of data:
#
# *  **Training data**, which includes the target unit_sales by date, store_nbr, and item_nbr and a unique id to label rows.
# *  **Test data**, with the date, store_nbr, item_nbr combinations that are to be predicted, along with the onpromotion                  information.
# *  **Supplementary data**, that may be useful in building our models. Such as: holidays_events.csv, transactions.csv, oil.csv,          items.csv, stores.csv, sample_submission.csv
#
# For Training and Testing data we have following attributes:
# *  id : This is a unique id to label rows.
# *  date :
# *  store_nbr:
# *  item_nbr :
# *  unit_sales: The target unit_sales can be integer or float.Negative values represent returns of that particular item.
# *  onpromotion: The onpromotion column tells whether that item_nbr was on promotion for a specified date and store_nbr.
#
# We will be merging the Supplementary data with the Training data to create a predictive model and further analysis using following attributes:
#
# **Item metadata**(Items marked as perishable have a score weight of 1.25; otherwise, the weight is 1.0.)
# *  item_nbr
# *  family
# *  class
# *  perishable
#
# **Store metadata**(Includes city, state, type, and cluster. cluster is a grouping of similar stores.)
# *  store_nbr
# *  city
# *  state
# *  type
# *  cluster
#
# **Oil metadata**(Ecuador is an oil-dependent country and it's economical health is highly vulnerable to shocks in oil prices.)
# *  Date
# *  Daily oil price
#
# **Transactions metadata**(The count of sales transactions for each date, store_nbr combination)
# *  date
# *  store_nbr
# *  transactions
#
# **Sample Submission metadata**
# *  id
# *  unit_sales
#
# **Holidays Events metadata**
# *  date
# *  type
# *  locale
# *  locale_name
# *  description
# *  transferred
#
# **Additional Notes**
# *  The training data does not include rows for items that had zero unit_sales for a store/date combination. There is no information as to whether or not the item was in stock for the store on the date, and teams will need to decide the best way to handle that situation. Also, there are a small number of items seen in the training data that aren't seen in the test data.
# *  Wages in the public sector are paid every two weeks on the 15 th and on the last day of the month. Supermarket sales could be affected by this.
# *  Pay special attention to the transferred column. A holiday that is transferred officially falls on that calendar day, but was moved to another date by the government. A transferred day is more like a normal day than a holiday. To find the day that it was actually celebrated, look for the corresponding row where type is Transfer. For example, the holiday Independencia de Guayaquil was transferred from 2012-10-09 to 2012-10-12, which means it was celebrated on 2012-10-12.
# *  Days that are type Bridge are extra days that are added to a holiday (e.g., to extend the break across a long weekend). These are frequently made up by the type Work Day which is a day not normally scheduled for work (e.g., Saturday) that is meant to payback the Bridge.
# *  A magnitude 7.8 earthquake struck Ecuador on April 16, 2016. People rallied in relief efforts donating water and other first need products which greatly affected supermarket sales for several weeks after the earthquake.

# %% [markdown]
# ### How will you operationalize the question?
# The goal of the project is to predict the unit sales for thousands of items sold at different Favorita stores located in Ecuador. We are given data on sales over time, Geography,items,transactions and by store for a large number of products sold by Corporacion Favorita across Ecuador. First, We will be doing an Exploratory Data analysis and Individual feature visualisations to get insights and information about the data by observing the Corporación Favorita business.
# To get an idea of the Sales Overview, we will be looking at:
#
# *  the total unit sales by store using the 'unit_sales' and 'Store_nbr' variables.
# *  the sales by Geography using the 'unit_sales' by 'state' and 'city' to see which state and city has a high margin of Sales
# *  the Sales over Time using the variables 'unit_sales' by 'date'to determine weekly, monthly sales.
# *  sales by item family using the variables 'unit_sales' by 'Family' to find the highest selling product families
# *  the Transaction.csv to see the ratio of sales and transactions over time which indicates the number of items purchased per transaction by date.
# * To find out the whether new product introductions affect the unit sales, we may need additional historical data.
# * Additional data may be needed to find the growth margin for favorita stores as compared to its competitors

# %% [markdown]
# ### How will you confirm your results?
#
#
# We are given a training dataset and a test data set. We will be training different forecasting models on our training data and test the predicted values on testing data.
#
# We can use simple or multiple regression to find if there is any statistically significant relationship between sales and other parameters given.
#
# Linear Regression finds great use in business, for sales forecasting based on the trends. If a company observes steady increase in sales with time - a linear regression analysis of the time series sales data helps the company forecast sales in future.
#
# We can use other statistical methods like chi square test and t-test to find relationship between different type of variables given which will help us to predict sales correctly.
#
# Also, we can segment products as "A", "B" and "C". In general, 20% of the items in a store brings 80% profit in sales. So, we can use classification techniques to classify the product families in different segments.
#
# We can use Support Vector Machine (SVM), XGBoost etc algorithms to build classification models.
#
# We can also implement Random Forest algorithm which trains a model several times on random sample of dataset to achieve good prediction performance.
#
# For evaluating the model used for prediction, we can perform cross validation which depicts a simple mean sqare difference between the observed and predicted values and gives us a measure of prediction accuracy.

# %% [markdown]
# ### What are assumptions / limitations?
#
# Following are the assumptions of data:
#
# *  They are assuming that the market and circumstances of the time period they provided the data is the same as the time period we are predicting the sales.
# *  They are assuming the transportation cost are same for these two time periods.
#
# These are the limitations of the data:
#
# * They have not provided any competitor data such as number of competitor stores near by which can affect the sales.
# * They have mentioned if the product in a particular store is on promotion or not. Some additional information on how long the promotions are running could be useful for prediction of sales, which is not provided here.
# * Ecuador is earthquake prone. Earthquake can affect the store sales, store safety stock, overall supply chain cost. Any data on natural disaster is not provided to analyze here.

# %% [markdown]
# ### What is the statement that you will be able to make after the analysis?
# * The Corporación Favorita dataset can be used to answer correlational/Predictive questions
# * We may want to look at the correlation between various features such as Unit Sales Vs Product Categories, Unit       Sales Vs Transaction, location etc. to name a few for our analysis.
# * After our analysis, we will be able to present a baseline model which will forecast the sales for Corporación Favorita.
#
# * We can also validate this model on the testing data to determine the accuracy of the model.
#
#
# Submissions can be evaluated on the Normalized Weighted Root Mean Squared Logarithmic Error (NWRMSLE), calculated as follows:
#
# ![image.png](attachment:image.png)
#
# where for row i, yi^ is the predicted unit_sales of an item and yi is the actual unit_sales; n is the total number of rows in the test set.
#
# The weights, wi, can be found in the items.csv file . Perishable items are given a weight of 1.25 where all other items are given a weight of 1.00.
#
# For each id in the test data set, we intend to predict the unit_sales. Because the metric uses ln(y+1), submissions are validated to ensure there are no negative predictions.
#
# * We can also answer most of the questions we proposed in the beginning.
#
# * We can suggest the grocery store about segmenting their product families and suggest SKU rationalization to optimize their profit

# %% [markdown]
# ## <font color= green> Team Members </font>
# *  Sohini Bhattacharya
# *  Aparajita Tiwari
# *  Amirtha Shridharan
# *  Rohini Bhandare

# %% [markdown]
# ##### Import required libraries

# %%
# Import Necessory Modules

import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import shutil
import seaborn as sns
sns.set(style = 'whitegrid', color_codes = True)
# %matplotlib inline

# %% [markdown]
# #### Read Datasets
# The training data includes dates, store and item information, whether that item was being promoted, as well as the unit sales. Additional files include supplementary information that may be useful in building your models.

# %%
# Create input path variable
Input_Path = 'G:/AnacondaProjects/Data/Gracery Sales Forecast/'

# Read Train dataset
df_train = pd.read_csv(Input_Path + 'train.csv', low_memory=False, nrows=10000000)
df_train.head()
#df_train.isnull().sum() # To check the total number of numm values in the column
# Out:
#    id        date  store_nbr  item_nbr  unit_sales  onpromotion
# 0   0  2013-01-01         25    103665         7.0          NaN
# 1   1  2013-01-01         25    105574         1.0          NaN
# 2   2  2013-01-01         25    105575         2.0          NaN
# 3   3  2013-01-01         25    108079         1.0          NaN
# 4   4  2013-01-01         25    108701         1.0          NaN

# %%
# Read Test dataset
df_test = pd.read_csv(Input_Path + 'test.csv')
df_test.head()
#df_test.isnull().sum() # To check the total number of numm values in the column
# Out:
#           id        date  store_nbr  item_nbr  onpromotion
# 0  125497040  2017-08-16          1     96995        False
# 1  125497041  2017-08-16          1     99197        False
# 2  125497042  2017-08-16          1    103501        False
# 3  125497043  2017-08-16          1    103520        False
# 4  125497044  2017-08-16          1    103665        False

# %%
# Read Holiday Events Dataset
df_holiday_events  = pd.read_csv(Input_Path + 'holidays_events.csv', parse_dates=['date'])
df_holiday_events.head()
#df_holiday_events.isnull().sum() # To check the total number of numm values in the column
# Out:
#         date     type    locale locale_name                    description  \
# 0 2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1 2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2 2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3 2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4 2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
# Read Items dataset
df_items = pd.read_csv(Input_Path + 'items.csv')
df_items.head()
#df_items.isnull().sum() # To check the total number of numm values in the column
# Out:
#    item_nbr        family  class  perishable
# 0     96995     GROCERY I   1093           0
# 1     99197     GROCERY I   1067           0
# 2    103501      CLEANING   3008           0
# 3    103520     GROCERY I   1028           0
# 4    103665  BREAD/BAKERY   2712           1

# %%
# Read Oil dataset
df_oil = pd.read_csv(Input_Path + 'oil.csv')
df_oil.head()
#df_oil.isnull().sum() # To check the total number of numm values in the column
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
# Read Stores dataset
df_stores  = pd.read_csv(Input_Path + 'stores.csv')
df_stores.head()
#df_stores.isnull().sum() # To check the total number of numm values in the column
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
# Read Transactions dataset
df_transactions = pd.read_csv(Input_Path + 'transactions.csv')
df_transactions.head()
#df_transactions.isnull().sum() # To check the total number of numm values in the column
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
# Read Sample Submission dataset
df_sample_submission  = pd.read_csv(Input_Path + 'sample_submission.csv')
df_sample_submission.head()
#df_sample_submission.isnull().sum() # To check the total number of numm values in the column
# Out:
#           id  unit_sales
# 0  125497040           0
# 1  125497041           0
# 2  125497042           0
# 3  125497043           0
# 4  125497044           0
